# %%
# STEP 1: Import Libraries and Load Data 
# Code adapted from Iqbal, M. (2026) 'Class_Demo_DT.ipynb', 
# Machine Learning module, CCT College Dublin.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Loading the abalone dataset
data = pd.read_csv('abalone.csv')

# Displaying the first 10 rows
print(data.head(10))
# Out:
#   Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
# 5   I   0.425     0.300   0.095        0.3515          0.1410          0.0775
# 6   F   0.530     0.415   0.150        0.7775          0.2370          0.1415
# 7   F   0.545     0.425   0.125        0.7680          0.2940          0.1495
# 8   M   0.475     0.370   0.125        0.5095          0.2165          0.1125
# 9   F   0.550     0.440   0.150        0.8945          0.3145          0.1510
#
#    Shell_weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7
# 5         0.120      8
# 6         0.330     20
# 7         0.260     16
# 8         0.165      9
# 9         0.320     19

# %%
# Checking the shape
print(data.shape)
# Out:
# (4180, 9)

# %%
#  STEP 2: Check for Missing Values and Duplicates 
# Code adapted from Iqbal, M. (2026) 'Class_Demo_DT.ipynb'

print("Missing values:")
print(data.isnull().sum())
# Out:
# Missing values:
# Sex               0
# Length            0
# Diameter          0
# Height            8
# Whole_weight      0
# Shucked_weight    5
# Viscera_weight    5
# Shell_weight      0
# Rings             0
# dtype: int64

# %%
duplicates = data.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
# Out:
# Number of duplicate rows: 3

# %%
# STEP 3: Remove null values and duplicates

# %%
#I'll drop the null values and check
data = data.dropna()
print(data.isnull().sum())
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole_weight      0
# Shucked_weight    0
# Viscera_weight    0
# Shell_weight      0
# Rings             0
# dtype: int64

# %%
data = data.drop_duplicates()
print(data.shape)
# Out:
# (4161, 9)

# %%
#and check again that it's been done
print(data.shape)
# Out:
# (4161, 9)

# %%
# --- STEP 4: Exploratory Data Analysis - Summary Statistics ---
# Code adapted from Iqbal, M. (2026) 'Class_Demo_DT.ipynb'

print(data.describe())
# Out:
#             Length     Diameter       Height  Whole_weight  Shucked_weight  \
# count  4161.000000  4161.000000  4161.000000   4161.000000     4161.000000
# mean      0.524275     0.408012     0.139302      0.827352        0.358292
# std       0.118785     0.098248     0.037911      0.483714        0.217122
# min       0.195000     0.140000     0.045000      0.035840        0.013500
# 25%       0.450000     0.350000     0.115000      0.442500        0.186500
# 50%       0.545000     0.425000     0.140000      0.800500        0.336000
# 75%       0.615000     0.480000     0.165000      1.154000        0.503000
# max       0.735000     0.580000     0.220000      2.141240        0.992980
#
#        Viscera_weight  Shell_weight        Rings
# count     4161.000000   4161.000000  4161.000000
# mean         0.180290      0.238143     9.913242
# std          0.108073      0.136146     3.126564
# min          0.007920      0.010420     4.000000
# 25%          0.093500      0.130000     8.000000
# 50%          0.171000      0.234500     9.000000
# 75%          0.253000      0.329500    11.000000
# max          0.474240      0.619580    20.000000

# %%
# STEP 5: Check Data Types
# Code adapted from Iqbal, M. (2026) 'Class_Demo_DT.ipynb', 
# Machine Learning module, CCT College Dublin.

print(data.dtypes)
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole_weight      float64
# Shucked_weight    float64
# Viscera_weight    float64
# Shell_weight      float64
# Rings               int64
# dtype: object

# %%
# --- STEP 6: Check Class Balance  or distribution for Sex (Target Variable) ---
# Code adapted from Iqbal, M. (2026) 'Class_Demo_DT.ipynb'

print(data['Sex'].value_counts())
# Out:
# Sex
# M    1523
# I    1338
# F    1300
# Name: count, dtype: int64

# %%
# --- Visualize Sex Distribution ---
# Code adapted from Iqbal, M. (2026) 'Class_Demo_DT.ipynb'

import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(x='Sex', data=data)
plt.title('Distribution of Sex Classes')
plt.show()

# %%
# --- Visualize Rings Distribution ---
# Code adapted from Iqbal, M. (2026) 'Class_Demo_DT.ipynb'

plt.hist(data['Rings'], bins=20, edgecolor='black')
plt.title('Distribution of Rings (Age)')
plt.xlabel('Rings')
plt.ylabel('Frequency')
plt.show()
